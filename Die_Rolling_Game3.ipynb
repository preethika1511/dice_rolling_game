# %%
import random

count=0
while True:
    choose= input("Do you want to roll the dice(Yes/No):").lower()
    if choose == "no":
        print(f"Thanks for playing!\nYou have rolled the dice {count} times")
        break
    elif choose== "yes":
        i,j= random.randint(1,6),random.randint(1,6)
        a=(i,j)
        count+=1
        print(f"({i},{j})") 
    else: 
        print("Invalid choice!")
# Out:
# Do you want to roll the dice(Yes/No): yes
# (2,3)
# Do you want to roll the dice(Yes/No): yES
# (5,1)
# Do you want to roll the dice(Yes/No): hdjf
# Invalid choice!
# Do you want to roll the dice(Yes/No): yes
# (6,4)
# Do you want to roll the dice(Yes/No): NO
# Thanks for playing!
# You have rolled the dice 3 times
